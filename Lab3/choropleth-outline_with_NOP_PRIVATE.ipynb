# %%
import pandas as pd
import requests

# %%
df = pd.read_csv('P3_GrantExport.csv',sep=';', usecols=[6,7,13]) # delimiter is ;

# %%
df
# Out:
#                                              Institution  \
# 0                                                    NaN
# 1      Faculté de Psychologie et des Sciences de l'Ed...
# 2      Kommission für das Corpus philosophorum medii ...
# 3      Abt. Handschriften und Alte Drucke Bibliothek ...
# 4                           Schweiz. Thesauruskommission
# 5      Séminaire de politique économique, d'économie ...
# 6      Institut für ökumenische Studien Université de...
# 7              Ostasiatisches Seminar Universität Zürich
# 8                                                    NaN
# 9      Laboratoire de Didactique et Epistémologie des...
# 10     Klinische Psychologie und Psychotherapie Insti...
# 11     Schweizerische Rechtsquellen c/o Universität Z...
# 12     Département de Sociologie Faculté des Sciences...
# 13     Institut für Volkswirtschaft WWZ / FGS Univers...
# 14            Soziologisches Institut Universität Zürich
# 15                                 Forschungszentrum FAL
# 16     Faculté de Psychologie et des Sciences de l'Ed...
# 17            Soziologisches Institut Universität Zürich
# 18                                                   NaN
# 19                                                   NaN
# 20     Faculté de Psychologie et des Sciences de l'Ed...
# 21                                                   NaN
# 22     Forschungsbereich Politisches Verhalten und Oe...
# 23     Département des langues et des littératures fr...
# 24                                                   NaN
# 25                                                   NaN
# 26            Schweizerische Gesellschaft für Volkskunde
# 27                         Kuratorium Carl J. Burckhardt
# 28                                                   NaN
# 29     Eidg. Forschungsanstalt für Wald, Schnee und L...
# ...                                                  ...
# 63939  Institut Sozialmanagement und Sozialpolitik Ho...
# 63940                Stiftung Bibliothek Werner Oechslin
# 63941  School of Geographical Sciences University of ...
# 63942                                                NaN
# 63943              CSIRO Marine and Atmospheric Research
# 63944                                                NaN
# 63945     Departement Geographie, SIE Universität Zürich
# 63946  CReAM Department of Economics University Colle...
# 63947                                                NaN
# 63948                                              Eawag
# 63949                      Catholic University of Bukavu
# 63950  Fondation Jean Monnet pour l'Europe Centre de ...
# 63951  Planning of Landscape and Urban Systems Instit...
# 63952  Forschungsanstalt Agroscope Reckenholz-Tänikon...
# 63953  Forschung und Beratung in Wirtschaft und Polit...
# 63954            Zoologisches Institut Universität Basel
# 63955  Zentrum für Religion, Wirtschaft und Politik T...
# 63956  Abteilung für Neuropsychologie Zentrum für Kog...
# 63957                                                NaN
# 63958         Abteilung für Indologie Universität Zürich
# 63959  Institut Religions, Cultures, Modernité FTSR U...
# 63960                                                NaN
# 63961  Department of Physics University of Massachusetts
# 63962                                                NaN
# 63963     Haute École d'art et de design - Genève HES-SO
# 63964  Departement Design Zürcher Hochschule der Küns...
# 63965  Institute Performing Arts and Film Zürcher Hoc...
# 63966  Department of Electrical Engineering and Compu...
# 63967  Département de Biologie Faculté des Sciences U...
# 63968  The Forsyth Institute Department of Microbiolo...
#
#                                               University Approved Amount
# 0                                   Nicht zuteilbar - NA        11619.00
# 1                              Université de Genève - GE        41022.00
# 2                NPO (Biblioth., Museen, Verwalt.) - NPO        79732.00
# 3                                 Universität Basel - BS        52627.00
# 4                NPO (Biblioth., Museen, Verwalt.) - NPO       120042.00
# 5                            Université de Fribourg - FR        53009.00
# 6                            Université de Fribourg - FR        25403.00
# 7                                Universität Zürich - ZH        47100.00
# 8                            Université de Lausanne - LA        25814.00
# 9                              Université de Genève - GE       360000.00
# 10                           Université de Fribourg - FR       153886.00
# 11               NPO (Biblioth., Museen, Verwalt.) - NPO       862200.00
# 12                             Université de Genève - GE       116991.00
# 13                                Universität Basel - BS       112664.00
# 14                               Universität Zürich - ZH         5000.00
# 15                           Université de Fribourg - FR       204018.00
# 16                             Université de Genève - GE       149485.00
# 17                               Universität Zürich - ZH        83983.00
# 18                                  Nicht zuteilbar - NA        38152.00
# 19                           Université de Lausanne - LA        14138.00
# 20                             Université de Genève - GE       164602.00
# 21                                 Universität Bern - BE       147795.00
# 22                               Universität Zürich - ZH        24552.00
# 23                             Université de Genève - GE        44802.00
# 24                                  Nicht zuteilbar - NA        56000.00
# 25                                  Nicht zuteilbar - NA       152535.00
# 26               NPO (Biblioth., Museen, Verwalt.) - NPO       225000.00
# 27               NPO (Biblioth., Museen, Verwalt.) - NPO       179124.00
# 28                               Universität Zürich - ZH        20000.00
# 29     Eidg. Forschungsanstalt für Wald,Schnee,Land -...       445198.00
# ...                                                  ...             ...
# 63939                           Hochschule Luzern - HSLU         1898.00
# 63940                                                NaN         9300.00
# 63941                                                NaN         9500.00
# 63942                                                NaN         4000.00
# 63943                                                NaN        11000.00
# 63944                                                NaN         7500.00
# 63945                                                NaN         8000.00
# 63946                                                NaN         9300.00
# 63947                                                NaN         7000.00
# 63948                                                NaN         6000.00
# 63949                                                NaN         4500.00
# 63950            NPO (Biblioth., Museen, Verwalt.) - NPO         2800.00
# 63951                                  ETH Zürich - ETHZ        99952.00
# 63952                Forschungsanstalten Agroscope - AGS        98040.00
# 63953                       Firmen/Privatwirtschaft - FP       100000.00
# 63954                                                NaN        10500.00
# 63955                             Universität Basel - BS        10030.00
# 63956                                                NaN         7870.00
# 63957                                                NaN         3150.00
# 63958                            Universität Zürich - ZH        10600.00
# 63959                        Université de Lausanne - LA         2515.00
# 63960                                                NaN         3500.00
# 63961                                                NaN         4000.00
# 63962                                                NaN         3550.00
# 63963                 HES de Suisse occidentale - HES-SO         3000.00
# 63964             Zürcher Fachhochschule (ohne PH) - ZFH         1000.00
# 63965             Zürcher Fachhochschule (ohne PH) - ZFH         2000.00
# 63966                                                NaN        10500.00
# 63967                                                NaN         9500.00
# 63968                                                NaN         7000.00
#
# [63969 rows x 3 columns]

# %%
df_new=df[(df.University.notnull())&(df["Approved Amount"]!='0.00')]
df_new=df_new[df_new['University'] != 'Nicht zuteilbar - NA']

# %%
universities=df_new.University.unique()

# %% [markdown]
# url = 'https://maps.googleapis.com/maps/api/geocode/json'
# params = {'address': 'University of Neuchâtel', 'region':'CH','key':'AIzaSyClUHUWJ3ZyRkYN3DbilaEGGcAtgvHKsdY'}
# r = requests.get(url, params=params)
# prueba=r.json()
# prueba['status']

# %%
import time
state=[]
null_names=[]
names=[]
count_good=0
count_bad=0
for university in universities:
    time.sleep(0.5)
    university_a=university.split(" -",1)[0]
    #print(university_a)
    url = 'https://maps.googleapis.com/maps/api/geocode/json'
    params = {'address': university_a,'region':'CH','key':'AIzaSyClUHUWJ3ZyRkYN3DbilaEGGcAtgvHKsdY'}
    r = requests.get(url, params=params)
    status=r.json()['status']
    results = r.json()['results']
    if status=='OK':
        flag=1
        count_good=count_good+1
        names.append(university)
        address=[]
        for result in results:
            for address_component in result['address_components']:
                if flag==1 and address_component['types']==['administrative_area_level_1', 'political']:
                    address.append(address_component['short_name'])
                    print(university_a,":", address[0])
                    state.append(address[0])
                    flag=0
                    break
        
    if status=='ZERO_RESULTS':
        count_bad=count_bad+1
        null_names.append(university)
# Out:
# AO Research Institute : Wien
# Biotechnologie Institut Thurgau : TG
# EPF Lausanne : VD
# ETH Zürich : ZH
# Facoltà di Teologia di Lugano : TI
# Haute école pédagogique BE, JU, NE : NE
# Haute école pédagogique du canton de Vaud : VD
# Hochschule Luzern : LU
# Institut für Kulturforschung Graubünden : GR
# Instituto Ricerche Solari Locarno : TI
# Interkant. Hochschule für Heilpädagogik ZH : ZH
# Istituto Svizzero di Roma : Lazio
# Kantonsspital St. Gallen : SG
# Paul Scherrer Institut : AG
# Physikal.-Meteorolog. Observatorium Davos : GR
# Pädag. Hochschule Tessin (Teilschule SUPSI) : TI
# Pädagogische Hochschule Bern : BE
# Pädagogische Hochschule Graubünden : GR
# Pädagogische Hochschule Luzern : LU
# Pädagogische Hochschule Schaffhausen : SH
# Pädagogische Hochschule Schwyz : SZ
# Pädagogische Hochschule St. Gallen : SG
# Pädagogische Hochschule Thurgau : TG
# Pädagogische Hochschule Wallis : VS
# Pädagogische Hochschule Zug : ZG
# Pädagogische Hochschule Zürich : ZH
# Robert Walser-Stiftung Bern : BE
# Staatsunabh. Theologische Hochschule Basel : BS
# Universität Basel : BS
# Universität Bern : BE
# Universität Luzern : LU
# Universität St. Gallen : SG
# Universität Zürich : ZH
# Université de Fribourg : FR
# Université de Genève : GE
# Université de Lausanne : VD

# %%
df_new2=df_new.copy()

# %%
df_new2['count'] =df_new2.groupby(['University'])['University'].transform('count')
del df_new2['Institution']
del df_new2['Approved Amount']
df_new2=df_new2.drop_duplicates().sort('count')
# Out:
# /Users/lemr/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
universities
# Out:
# array(['AO Research Institute - AORI',
#        'Allergie- und Asthmaforschung - SIAF',
#        'Berner Fachhochschule - BFH',
#        'Biotechnologie Institut Thurgau - BITG',
#        "Centre de rech. sur l'environnement alpin - CREALP",
#        'EPF Lausanne - EPFL', 'ETH Zürich - ETHZ',
#        'Eidg. Anstalt für Wasserversorgung - EAWAG',
#        'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#        'Eidg. Hochschulinstitut für Berufsbildung - EHB',
#        'Eidg. Material und Prüfungsanstalt - EMPA',
#        'Ente Ospedaliero Cantonale - EOC',
#        'Fachhochschule Kalaidos - FHKD',
#        'Fachhochschule Nordwestschweiz (ohne PH) - FHNW',
#        'Fachhochschule Ostschweiz - FHO',
#        'Facoltà di Teologia di Lugano - FTL',
#        'Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS',
#        'Firmen/Privatwirtschaft - FP',
#        'Forschungsanstalten Agroscope - AGS',
#        'Forschungsinstitut für Opthalmologie - IRO',
#        'Forschungsinstitut für biologischen Landbau - FIBL',
#        'Forschungskommission SAGW',
#        'Franklin University Switzerland - FUS',
#        'Friedrich Miescher Institute - FMI',
#        'HES de Suisse occidentale - HES-SO',
#        'Haute école pédagogique BE, JU, NE - HEPBEJUNE',
#        'Haute école pédagogique du canton de Vaud - HEPL',
#        'Haute école pédagogique fribourgeoise - HEPFR',
#        'Hochschule Luzern - HSLU', 'Idiap Research Institute - IDIAP',
#        'Inst. Suisse de Spéléologie et Karstologie - ISSKA',
#        'Inst. de Hautes Etudes Internat. et du Dév - IHEID',
#        'Inst. universit. romand de Santé au Travail - IST',
#        'Institut Universitaire Kurt Bösch - IUKB',
#        'Institut für Kulturforschung Graubünden - IKG',
#        'Instituto Ricerche Solari Locarno - IRSOL',
#        'Interkant. Hochschule für Heilpädagogik ZH - HfH',
#        'Istituto Svizzero di Roma - ISR',
#        'Kantonsspital St. Gallen - KSPSG',
#        'NPO (Biblioth., Museen, Verwalt.) - NPO',
#        'Paul Scherrer Institut - PSI',
#        'Physikal.-Meteorolog. Observatorium Davos - PMOD',
#        'Pädag. Hochschule Tessin (Teilschule SUPSI) - ASP',
#        'Pädagogische Hochschule Bern - PHBern',
#        'Pädagogische Hochschule Graubünden - PHGR',
#        'Pädagogische Hochschule Luzern - PHLU',
#        'Pädagogische Hochschule Nordwestschweiz - PHFHNW',
#        'Pädagogische Hochschule Schaffhausen - PHSH',
#        'Pädagogische Hochschule Schwyz - PHSZ',
#        'Pädagogische Hochschule St. Gallen - PHSG',
#        'Pädagogische Hochschule Thurgau - PHTG',
#        'Pädagogische Hochschule Wallis - PHVS',
#        'Pädagogische Hochschule Zug - PHZG',
#        'Pädagogische Hochschule Zürich - PHZFH',
#        'Robert Walser-Stiftung Bern - RWS',
#        'SUP della Svizzera italiana - SUPSI',
#        'Schweiz. Hochschule für Logopädie Rorschach - SHLR',
#        'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA',
#        'Schweizer Kompetenzzentrum Sozialwissensch. - FORS',
#        'Schweizer Paraplegiker Forschung - SPF',
#        'Staatsunabh. Theologische Hochschule Basel - STHB',
#        'Swiss Center for Electronics and Microtech. - CSEM',
#        'Swiss Institute of Bioinformatics - SIB',
#        'Università della Svizzera italiana - USI',
#        'Universität Basel - BS', 'Universität Bern - BE',
#        'Universität Luzern - LU', 'Universität St. Gallen - SG',
#        'Universität Zürich - ZH', 'Université de Fribourg - FR',
#        'Université de Genève - GE', 'Université de Lausanne - LA',
#        'Université de Neuchâtel - NE', 'Weitere Institute - FINST',
#        'Weitere Spitäler - ASPIT', 'Zürcher Fachhochschule (ohne PH) - ZFH'], dtype=object)

# %%
df_institutions=df_new[((df_new['Institution'].notnull()) & ((df_new['University']=='NPO (Biblioth., Museen, Verwalt.) - NPO') | (df_new['University']=='Firmen/Privatwirtschaft - FP')))]
del df_institutions['Approved Amount']
##Private institutions
private=df_institutions.drop_duplicates().sort('count')[(df_institutions.drop_duplicates().sort('count')['University'])==('Firmen/Privatwirtschaft - FP')]['Institution']

##NOP
nop=df_institutions.drop_duplicates().sort('count')[(df_institutions.drop_duplicates().sort('count')['University'])==('NPO (Biblioth., Museen, Verwalt.) - NPO')]['Institution']
# Out:
# /Users/lemr/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /Users/lemr/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:7: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
###Private
import time
state_private=[]
null_names_private=[]
names_private=[]
count_good_private=0
count_bad_private=0
for priv in private:
    time.sleep(0.5)
    url = 'https://maps.googleapis.com/maps/api/geocode/json'
    params = {'address': priv,'region':'CH','key':'AIzaSyClUHUWJ3ZyRkYN3DbilaEGGcAtgvHKsdY'}
    r = requests.get(url, params=params)
    status=r.json()['status']
    results = r.json()['results']
    if status=='OK':
        flag=1
        count_good_private=count_good_private+1
        names_private.append(priv)
        address_private=[]
        for result in results:
            for address_component in result['address_components']:
                if flag==1 and address_component['types']==['administrative_area_level_1', 'political']:
                    address_private.append(address_component['short_name'])
                    print(priv,":", address_private[0])
                    state_private.append(address_private[0])
                    flag=0
                    break
        
    if status=='ZERO_RESULTS':
        count_bad_private=count_bad_private+1
        null_names.append(priv)
# Out:
# St. Galler Wirtschafts-Consulting (SWC) Schmid, Widmer, Prey AG : AG
# Rütter Soceco AG : AG
# Groupe Limnoceane Institut de géologie Université de Neuchâtel : NE
# Biospectra AG : AG
# BSS Volkswirtschaftliche Beratung AG : AG
# Ciba-Geigy AG Forschungszentrum Marly : FR
# Forschungszentrum ABB Schweiz AG : AG
# Ateliers et Laboratoire C R E P H A R T : Grand Casablanca
# Gesundheitsdepartement des Kantons Basel-Stadt : BS
# Unitectra AG : AG
# FEINTOOL AG : AG
# Département de Physique Université de Fribourg : FR
# TOGO AG : WB
# Schaffner Elektronik AG : AG
# Departement Geschichte Universität Basel : BS
# Jäckli Geologie Dr. Heinrich Jäckli AG : AG
# SKK Landschaftsarchitekten AG : AG
# Alter Ego : Hiroshima-ken
# Alcatel Schweiz AG : AG
# Cellulose Attisholz AG : AG
# Corporate Communication Von Roll Management AG : AG
# HCP Planen und Beraten für das Gesundheitswesen AG : AG
# ASIT : Van
# Health Management Institute : Jiangsu Sheng
# MOR Informatik AG : AG
# Colenco Power Consulting AG : AG
# Planconsult W+B AG : AG
# Ernst Basler + Partner AG : AG
# Lamprecht und Stamm Sozialforschung und Beratung AG : AG
# Rytec Partner AG : AG
# Aqua-System AG : AG
# Metron Raumplanung AG : AG
# Rapp Ingenieur + Informatik AG : AG
# Abteilung Pharmakologie/Neurobiologie Biozentrum der Universität Basel : BS
# Geoexpert AG : AG
# Gruppe CORSO : LU
# HOLDERBANK Management und Beratung AG : AG
# Interdisziplinäre Berater- und Forschungsgruppe AG : AG
# B & S Ingenieur AG : DL
# INFRAS : AP
# Siemens Building Technologies AG : AG
# Suiselectra Ingenieurunternehmung AG : AG
# Prognos AG : AG
# IC Infraconsult AG : AG
# BHP - Hanser und Partner AG : AG
# Aarproject AG : AG
# GEO Partner AG : AG
# CTU - Conzepte Technik Umwelt AG : AG
# VIRTÙ Public Affairs AG : AG
# Küpat AG : AG
# Carbotech AG : AG
# BMG Engineering AG : AG
# PSP AG : AG
# Geoprognos ag : AG
# MEDICOAT AG : AG
# Bioengineering AG : AG
# Scherrer Ingenieurbüro AG : AG
# Institut Montana : ZG
# Kochkom : Kareliya Republits
# ISE Software AG High-Tech-Center : Mie Prefecture
# R3 Security Engineering : England
# Wirtschafts-Mathematik AG : AG
# VA TECH WABAG AG : AG
# Sulzer Chemtech AG : AG
# Institut für Kommunikation und Marketing Hochschule Luzern - Wirtschaft Fachhochschule Zentralschweiz : LU
# Stöckli A. & J. AG : AG
# Batrec AG : AG
# Metron Orts- und Regionalplanung AG : AG
# TECOVA AG : AG
# Lehrstuhl für Schweizer Politik Universität Zürich : ZH
# Büro für arbeits- und sozialpolitische Studien (Büro BASS), Bern : BE
# Albrecht & Partner AG : AG
# Wirtschafts- und Politikberatung Econcept AG : AG
# INFRAS AG : AG
# ABW Architektur + Raumplanung AG : AG
# Schwabe u. Co. AG : AG

# %%
state_private
# Out:
# ['AG',
#  'AG',
#  'NE',
#  'AG',
#  'AG',
#  'FR',
#  'AG',
#  'Grand Casablanca',
#  'BS',
#  'AG',
#  'AG',
#  'FR',
#  'WB',
#  'AG',
#  'BS',
#  'AG',
#  'AG',
#  'Hiroshima-ken',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'Van',
#  'Jiangsu Sheng',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'BS',
#  'AG',
#  'LU',
#  'AG',
#  'AG',
#  'DL',
#  'AP',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'ZG',
#  'Kareliya Republits',
#  'Mie Prefecture',
#  'England',
#  'AG',
#  'AG',
#  'AG',
#  'LU',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'ZH',
#  'BE',
#  'AG',
#  'AG',
#  'AG',
#  'AG',
#  'AG']

# %%
names_priv
# Out:
# ['St. Galler Wirtschafts-Consulting (SWC) Schmid, Widmer, Prey AG',
#  'Rütter Soceco AG',
#  'Groupe Limnoceane Institut de géologie Université de Neuchâtel',
#  'Biospectra AG',
#  'BSS Volkswirtschaftliche Beratung AG',
#  'Ciba-Geigy AG Forschungszentrum Marly',
#  'Forschungszentrum ABB Schweiz AG',
#  'Ateliers et Laboratoire C R E P H A R T',
#  'Gesundheitsdepartement des Kantons Basel-Stadt',
#  'Unitectra AG',
#  'FEINTOOL AG',
#  'Département de Physique Université de Fribourg',
#  'TOGO AG',
#  'Schaffner Elektronik AG',
#  'Departement Geschichte Universität Basel',
#  'Jäckli Geologie Dr. Heinrich Jäckli AG',
#  'SKK Landschaftsarchitekten AG',
#  'Alter Ego',
#  'Alcatel Schweiz AG',
#  'Cellulose Attisholz AG',
#  'Corporate Communication Von Roll Management AG',
#  'HCP Planen und Beraten für das Gesundheitswesen AG',
#  'ASIT',
#  'Health Management Institute',
#  'MOR Informatik AG',
#  'Colenco Power Consulting AG',
#  'Planconsult W+B AG',
#  'Ernst Basler + Partner AG',
#  'Lamprecht und Stamm Sozialforschung und Beratung AG',
#  'Rytec Partner AG',
#  'Aqua-System AG',
#  'Metron Raumplanung AG',
#  'Rapp Ingenieur + Informatik AG',
#  'Abteilung Pharmakologie/Neurobiologie Biozentrum der Universität Basel',
#  'Geoexpert AG',
#  'Gruppe CORSO',
#  'HOLDERBANK Management und Beratung AG',
#  'Interdisziplinäre Berater- und Forschungsgruppe AG',
#  'B & S Ingenieur AG',
#  'INFRAS',
#  'Siemens Building Technologies AG',
#  'Suiselectra Ingenieurunternehmung AG',
#  'Prognos AG',
#  'IC Infraconsult AG',
#  'BHP - Hanser und Partner AG',
#  'Aarproject AG',
#  'GEO Partner AG',
#  'CTU - Conzepte Technik Umwelt AG',
#  'VIRTÙ Public Affairs AG',
#  'Küpat AG',
#  'Carbotech AG',
#  'BMG Engineering AG',
#  'PSP AG',
#  'Geoprognos ag',
#  'MEDICOAT AG',
#  'Bioengineering AG',
#  'Scherrer Ingenieurbüro AG',
#  'Institut Montana',
#  'Kochkom',
#  'ISE Software AG High-Tech-Center',
#  'R3 Security Engineering',
#  'Wirtschafts-Mathematik AG',
#  'VA TECH WABAG AG',
#  'Sulzer Chemtech AG',
#  'Institut für Kommunikation und Marketing Hochschule Luzern - Wirtschaft Fachhochschule Zentralschweiz',
#  'Stöckli A. & J. AG',
#  'Batrec AG',
#  'Metron Orts- und Regionalplanung AG',
#  'TECOVA AG',
#  'Lehrstuhl für Schweizer Politik Universität Zürich',
#  'Büro für arbeits- und sozialpolitische Studien (Büro BASS), Bern',
#  'Albrecht & Partner AG',
#  'Wirtschafts- und Politikberatung Econcept AG',
#  'INFRAS AG',
#  'ABW Architektur + Raumplanung AG',
#  'Schwabe u. Co. AG']

# %%
null_names_private
# Out:
# []

# %%
state_nop=[]
null_names_nop=[]
names_nop=[]
count_good_nop=0
count_bad_nop=0
for nop_ in nop:
    time.sleep(0.5)
    url = 'https://maps.googleapis.com/maps/api/geocode/json'
    params = {'address': nop_,'region':'CH','key':'AIzaSyClUHUWJ3ZyRkYN3DbilaEGGcAtgvHKsdY'}
    r = requests.get(url, params=params)
    status=r.json()['status']
    results = r.json()['results']
    if status=='OK':
        flag=1
        count_good_nop=count_good_nop+1
        names_nop.append(nop_)
        address_nop=[]
        for result in results:
            for address_component in result['address_components']:
                if flag==1 and address_component['types']==['administrative_area_level_1', 'political']:
                    address_nop.append(address_component['short_name'])
                    print(nop_,":", address_nop[0])
                    state_nop.append(address_nop[0])
                    flag=0
                    break
        
    if status=='ZERO_RESULTS':
        count_bad_nop=count_bad_nop+1
        null_names.append(nop_)
# Out:
# Denkmalpflege und Archäologie des Kantons Luzern : LU
# Archives de l'Etat de Neuchâtel : NE
# Kantonsschule Riesbach : ZH
# Archivio di Stato del Canton Ticino : TI
# Amt für Archäologie des Kantons Thurgau : TG
# Fachstelle für Gleichstellung Frau und Mann des Kantons Zürich : ZH
# Institut de Microbiologie Université de Lausanne : VD
# Kanton. Aufsichtsstelle Datenschutz Justiz-, Polizei- und Militärdirektion : Guangdong
# Abteilung Mikrobiologie Biozentrum Universität Basel : BS
# Alter Ego : Hiroshima-ken
# Justizdirektion Nidwalden : Nordwest
# Vitrocentre Romont : FR
# oikos foundation Institute for Economy and the Environment University of St.Gallen : SG
# Wissensstadt Davos : GR
# Amt für Raumentwicklung Baudirektion Kanton Zürich : ZH
# Kunstmuseum Bern : BE
# Musée d'art et d'histoire de Fribourg : FR
# Divisione della Cultura Dipartimento dell'istruzione e della cultura del Cantone Ticino : TI
# Archäologie Schweiz : BE
# Dépt de langue & littérature allemandes Faculté des lettres Université de Genève : GE
# Stiftsarchiv : NDS
# Bibliothèque cantonale universitaire : FR
# Archives D'Etat de Genève Etat de Genève : GE
# Museum Tinguely : BS
# Geschichte der Naturwissenschaften MN-Fakultät Universität Zürich : ZH
# Unite d'oncologie experimentale CHUV - Université de Lausanne : VD
# Musikwissenschaftliches Institut Universität Zürich : ZH
# Fachbereich Mathematik Departement Mathematik und Informatik Universität Basel : BS
# Abteilung Geowissenschaften Naturhistorisches Museum Basel : BS
# Fondation Guy de Pourtalès Université de Lausanne : VD
# Webster University : CA
# Nano-Cluster Bodensee : NDS
# Centre de recherche MISC Faculté des sciences sociales et politiques Université de Lausanne : VD
# Conservatoire de Lausanne : VD
# WDA Forum AG : AG
# Aargauer Kantonsschule Baden : AG
# Muséum d'histoire naturelle : Bourgogne Franche-Comté
# Erziehungsdepartement Obwalden : OW
# Kantonale Fachstelle für Archäologie Staatsarchiv des Kantons Nidwalden : Nordwest
# Zentralbibliothek Zürich : ZH
# Bibliothèque cantonale et universitaire : FR
# Staatsarchiv Fribourg : FR
# SIDOS : Shida Kartli
# Obergericht Zürich : ZH
# Bibliothek Staatsarchiv des Kantons Zürich : ZH
# Naturmuseum Winterthur : ZH
# Kantonsarchäologie Aargau : AG
# Direction des Musées cantonaux du Valais : VS
# GGG : Saitama-ken
# Institut für Bildungsevaluation Assoziiertes Inst. der Universität Zürich : ZH
# CABI : Chocó
# Musée Historique de Lausanne : VD
# Rechtswissenschaftliches Institut Universität Zürich : ZH
# Site et Musée romains d'Avenches : VD
# Kantonsarchäologie Basel-Landschaft : BL
# Erwerbungsabteilung Zentralbibliothek Luzern : LU
# Sozialversicherungsgericht des Kantons Zürich : ZH
# Faculté des sciences économiques et sociales, Décanat Université de Genève : GE
# EDA : Edo
# Bildungsplanung / Biblothek Bildungsdirektion des Kantons Zürich : ZH
# Arbeitslehrerinnenseminar des Kantons Zürich : ZH
# Archäologischer Dienst des Kantons Bern : BE
# Appellationsgericht Basel-Stadt : BS
# Kantonale Denkmalpflege Zug : ZG
# Kunstmuseum : BE
# Service archéologique Canton de Fribourg : FR
# Muséum d'Histoire Naturelle : Bourgogne Franche-Comté
# Institut d'études médiévales Université de Fribourg : FR
# Gymnase du Bugnon : Auvergne-Rhône-Alpes
# Archives de l'Etat de Fribourg : FR
# Laténium Parc et musée d'archéologie de Neuchâtel : NE
# Liceo di Lugano 2 : TI
# Museum des Kantons Thurgau : TG
# Kantonsschule Baden : AG
# Tribunal fédéral : VD
# Kantonsarchäologie St. Gallen : SG
# Liceo Cantonale Locarno : TI
# Stadtbibliothek Schaffhausen : SH
# Staatsarchiv Basel Stadt : BS
# Liceo Cantonale 1 : Pichincha
# Literargymnasium Kantonsschule Rämibühl Zürich : ZH
# Arche Verlag AG : AG
# Musée d'ethnographie de Genève : GE
# Institut de recherches économiques Université de Neuchâtel : NE
# Mathematisch-naturwissensch. Gymnasium Kantonsschule Rämibühl Zürich : ZH
# Stiftsbibliothek St. Gallen : SG
# Historisches Museum : TG
# Liceo Cantonale : Pichincha
# Musées d'art et d'histoire de Genève : GE
# Bibliothek Kantonsschule Luzern : LU
# Staatsarchiv : NDS
# Kantonsschule Sargans : SG
# Büro für Archäologie der Stadt Zürich : ZH
# Forum Ost-West : HE
# Historische und Antiquarische Gesellschaft zu Basel : BS
# Schweizerisches Nationalmuseum Landesmuseum Zürich : ZH
# Kuratorium der Helvetia Sacra c/o Staatsarchiv Basel : BS
# Archives d'Etat de Genève : GE
# Tschudi-Kommission der AGGS Staatsarchiv Zürich : ZH
# Kommission des Phonogrammarchivs Universität Zürich : ZH
# Ecole Suisse d'archéologie en Grèce  Univ. de Lausanne : VD
# Département des travaux publics du Canton de Vaud : VD
# Archäologische Bodenforschung des Kantons Basel-Stadt : BS
# Staatsarchiv Uri : UR
# Hochalpine Forschungsstationen Jungfraujoch & Gornergrat Universität Bern : BE
# Zentralbibliothek Solothurn : SO
# Institut für chirurgische Technologien und Biomechanik (ISTB) Universität Bern : BE
# Staatsarchiv des Kantons Luzern : LU
# École des Hautes Études Commerciales Université de Lausanne : VD
# Strittmatter + Partner AG : AG
# Tk3 AG : AG
# Staatsarchiv des Kantons Bern : BE
# Monuments historiques et archéologie du canton de Vaud : VD
# Freies Gymnasium Zürich : ZH
# Hôpital de Zone de Morges : VD
# Département de Biologie Moléculaire Faculté des Sciences Université de Genève : GE
# Kantonsschule Zug : ZG
# Ecole supérieure de Commerce : Normandie
# Observatoire Cantonal de Neuchâtel : NE
# Kantonsarchäologie Schaffhausen : SH
# Staatsarchiv Graubünden : GR
# Abwasserverband Altenrhein : SG
# Conservatoire et jardin botaniques de la Ville de Genève : GE
# Natur-Museum Luzern : LU
# Institut de Zoologie Faculté des Sciences Université de Neuchâtel : NE
# Département de Biologie Cellulaire Faculté des Sciences Université de Genève : GE
# Kantonsschule Freudenberg : NRW
# Ecole supérieur de commerce de la ville de Sion : VS
# Collège Cantonal Saint-Michel : Languedoc-Roussillon-Midi-Pyrénées
# Centre de Recherche de Genève : GE
# Institut für Geophysik ETH Zürich : ZH
# Forschungsgruppe für Management im Gesundheitswesen an der Fachhoch- schule für Wirtschaft St. Gallen : SG
# Departement Umweltsystemwissenschaften ETH Zürich : ZH
# BAK Konjunkturforschung Basel AG : AG
# Trimarca AG : AG
# Wasser- und Energiewirtschaftsamt des Kantons Bern : BE
# Sozialmedizinische Beratungsstelle für Jugendliche Integrative Psych. Winterthur : ZH
# Abteilung Biochemie Biozentrum Universität Basel : BS
# Gesundheitsdienst der Stadt Bern : BE
# Sukkulentensammlung Zürich : ZH
# FORS c/o Université de Lausanne : VD

# %%
state_nop
# Out:
# ['LU',
#  'NE',
#  'ZH',
#  'TI',
#  'TG',
#  'ZH',
#  'VD',
#  'Guangdong',
#  'BS',
#  'Hiroshima-ken',
#  'Nordwest',
#  'FR',
#  'SG',
#  'GR',
#  'ZH',
#  'BE',
#  'FR',
#  'TI',
#  'BE',
#  'GE',
#  'NDS',
#  'FR',
#  'GE',
#  'BS',
#  'ZH',
#  'VD',
#  'ZH',
#  'BS',
#  'BS',
#  'VD',
#  'CA',
#  'NDS',
#  'VD',
#  'VD',
#  'AG',
#  'AG',
#  'Bourgogne Franche-Comté',
#  'OW',
#  'Nordwest',
#  'ZH',
#  'FR',
#  'FR',
#  'Shida Kartli',
#  'ZH',
#  'ZH',
#  'ZH',
#  'AG',
#  'VS',
#  'Saitama-ken',
#  'ZH',
#  'Chocó',
#  'VD',
#  'ZH',
#  'VD',
#  'BL',
#  'LU',
#  'ZH',
#  'GE',
#  'Edo',
#  'ZH',
#  'ZH',
#  'BE',
#  'BS',
#  'ZG',
#  'BE',
#  'FR',
#  'Bourgogne Franche-Comté',
#  'FR',
#  'Auvergne-Rhône-Alpes',
#  'FR',
#  'NE',
#  'TI',
#  'TG',
#  'AG',
#  'VD',
#  'SG',
#  'TI',
#  'SH',
#  'BS',
#  'Pichincha',
#  'ZH',
#  'AG',
#  'GE',
#  'NE',
#  'ZH',
#  'SG',
#  'TG',
#  'Pichincha',
#  'GE',
#  'LU',
#  'NDS',
#  'SG',
#  'ZH',
#  'HE',
#  'BS',
#  'ZH',
#  'BS',
#  'GE',
#  'ZH',
#  'ZH',
#  'VD',
#  'VD',
#  'BS',
#  'UR',
#  'BE',
#  'SO',
#  'BE',
#  'LU',
#  'VD',
#  'AG',
#  'AG',
#  'BE',
#  'VD',
#  'ZH',
#  'VD',
#  'GE',
#  'ZG',
#  'Normandie',
#  'NE',
#  'SH',
#  'GR',
#  'SG',
#  'GE',
#  'LU',
#  'NE',
#  'GE',
#  'NRW',
#  'VS',
#  'Languedoc-Roussillon-Midi-Pyrénées',
#  'GE',
#  'ZH',
#  'SG',
#  'ZH',
#  'AG',
#  'AG',
#  'BE',
#  'ZH',
#  'BS',
#  'BE',
#  'ZH',
#  'VD']

# %%
names_nop
# Out:
# ['Denkmalpflege und Archäologie des Kantons Luzern',
#  "Archives de l'Etat de Neuchâtel",
#  'Kantonsschule Riesbach',
#  'Archivio di Stato del Canton Ticino',
#  'Amt für Archäologie des Kantons Thurgau',
#  'Fachstelle für Gleichstellung Frau und Mann des Kantons Zürich',
#  'Institut de Microbiologie Université de Lausanne',
#  'Kanton. Aufsichtsstelle Datenschutz Justiz-, Polizei- und Militärdirektion',
#  'Abteilung Mikrobiologie Biozentrum Universität Basel',
#  'Alter Ego',
#  'Justizdirektion Nidwalden',
#  'Vitrocentre Romont',
#  'oikos foundation Institute for Economy and the Environment University of St.Gallen',
#  'Wissensstadt Davos',
#  'Amt für Raumentwicklung Baudirektion Kanton Zürich',
#  'Kunstmuseum Bern',
#  "Musée d'art et d'histoire de Fribourg",
#  "Divisione della Cultura Dipartimento dell'istruzione e della cultura del Cantone Ticino",
#  'Archäologie Schweiz',
#  'Dépt de langue & littérature allemandes Faculté des lettres Université de Genève',
#  'Stiftsarchiv',
#  'Bibliothèque cantonale universitaire',
#  "Archives D'Etat de Genève Etat de Genève",
#  'Museum Tinguely',
#  'Geschichte der Naturwissenschaften MN-Fakultät Universität Zürich',
#  "Unite d'oncologie experimentale CHUV - Université de Lausanne",
#  'Musikwissenschaftliches Institut Universität Zürich',
#  'Fachbereich Mathematik Departement Mathematik und Informatik Universität Basel',
#  'Abteilung Geowissenschaften Naturhistorisches Museum Basel',
#  'Radar, Satellite and Nowcasting Division Meteo Svizzera',
#  'Fondation Guy de Pourtalès Université de Lausanne',
#  'Webster University',
#  'Nano-Cluster Bodensee',
#  'Centre de recherche MISC Faculté des sciences sociales et politiques Université de Lausanne',
#  'Conservatoire de Lausanne',
#  'WDA Forum AG',
#  'Aargauer Kantonsschule Baden',
#  "Muséum d'histoire naturelle",
#  'Erziehungsdepartement Obwalden',
#  'Kantonale Fachstelle für Archäologie Staatsarchiv des Kantons Nidwalden',
#  'Zentralbibliothek Zürich',
#  'Bibliothèque cantonale et universitaire',
#  'Staatsarchiv Fribourg',
#  'SIDOS',
#  'Obergericht Zürich',
#  'Bibliothek Staatsarchiv des Kantons Zürich',
#  'Naturmuseum Winterthur',
#  'Kantonsarchäologie Aargau',
#  'Direction des Musées cantonaux du Valais',
#  'GGG',
#  'Institut für Bildungsevaluation Assoziiertes Inst. der Universität Zürich',
#  'CABI',
#  'Musée Historique de Lausanne',
#  'Rechtswissenschaftliches Institut Universität Zürich',
#  "Site et Musée romains d'Avenches",
#  'Kantonsarchäologie Basel-Landschaft',
#  'Erwerbungsabteilung Zentralbibliothek Luzern',
#  'Sozialversicherungsgericht des Kantons Zürich',
#  'Faculté des sciences économiques et sociales, Décanat Université de Genève',
#  'EDA',
#  'Bildungsplanung / Biblothek Bildungsdirektion des Kantons Zürich',
#  'Arbeitslehrerinnenseminar des Kantons Zürich',
#  'Archäologischer Dienst des Kantons Bern',
#  'Appellationsgericht Basel-Stadt',
#  'Kantonale Denkmalpflege Zug',
#  'Kunstmuseum',
#  'Service archéologique Canton de Fribourg',
#  "Muséum d'Histoire Naturelle",
#  "Institut d'études médiévales Université de Fribourg",
#  'Gymnase du Bugnon',
#  "Archives de l'Etat de Fribourg",
#  "Laténium Parc et musée d'archéologie de Neuchâtel",
#  'Liceo di Lugano 2',
#  'Museum des Kantons Thurgau',
#  'Kantonsschule Baden',
#  'Tribunal fédéral',
#  'Kantonsarchäologie St. Gallen',
#  'Liceo Cantonale Locarno',
#  'Stadtbibliothek Schaffhausen',
#  'Staatsarchiv Basel Stadt',
#  'Liceo Cantonale 1',
#  'Literargymnasium Kantonsschule Rämibühl Zürich',
#  'Arche Verlag AG',
#  "Musée d'ethnographie de Genève",
#  'Institut de recherches économiques Université de Neuchâtel',
#  'Mathematisch-naturwissensch. Gymnasium Kantonsschule Rämibühl Zürich',
#  'Stiftsbibliothek St. Gallen',
#  'Historisches Museum',
#  'Liceo Cantonale',
#  "Musées d'art et d'histoire de Genève",
#  'Bibliothek Kantonsschule Luzern',
#  'Staatsarchiv',
#  'Kantonsschule Sargans',
#  'Büro für Archäologie der Stadt Zürich',
#  'Forum Ost-West',
#  'Historische und Antiquarische Gesellschaft zu Basel',
#  'Schweizerisches Nationalmuseum Landesmuseum Zürich',
#  'Kuratorium der Helvetia Sacra c/o Staatsarchiv Basel',
#  "Archives d'Etat de Genève",
#  'Tschudi-Kommission der AGGS Staatsarchiv Zürich',
#  'Kommission des Phonogrammarchivs Universität Zürich',
#  "Ecole Suisse d'archéologie en Grèce  Univ. de Lausanne",
#  'Département des travaux publics du Canton de Vaud',
#  'Archäologische Bodenforschung des Kantons Basel-Stadt',
#  'Staatsarchiv Uri',
#  'Hochalpine Forschungsstationen Jungfraujoch & Gornergrat Universität Bern',
#  'Zentralbibliothek Solothurn',
#  'Institut für chirurgische Technologien und Biomechanik (ISTB) Universität Bern',
#  'Staatsarchiv des Kantons Luzern',
#  'École des Hautes Études Commerciales Université de Lausanne',
#  'Strittmatter + Partner AG',
#  'Tk3 AG',
#  'Staatsarchiv des Kantons Bern',
#  'Monuments historiques et archéologie du canton de Vaud',
#  'Freies Gymnasium Zürich',
#  'Hôpital de Zone de Morges',
#  'Département de Biologie Moléculaire Faculté des Sciences Université de Genève',
#  'Kantonsschule Zug',
#  'Ecole supérieure de Commerce',
#  'Observatoire Cantonal de Neuchâtel',
#  'Kantonsarchäologie Schaffhausen',
#  'Staatsarchiv Graubünden',
#  'Abwasserverband Altenrhein',
#  'Conservatoire et jardin botaniques de la Ville de Genève',
#  'Natur-Museum Luzern',
#  'Institut de Zoologie Faculté des Sciences Université de Neuchâtel',
#  'Département de Biologie Cellulaire Faculté des Sciences Université de Genève',
#  'Kantonsschule Freudenberg',
#  'Ecole supérieur de commerce de la ville de Sion',
#  'Collège Cantonal Saint-Michel',
#  'Centre de Recherche de Genève',
#  'Institut für Geophysik ETH Zürich',
#  'Forschungsgruppe für Management im Gesundheitswesen an der Fachhoch- schule für Wirtschaft St. Gallen',
#  'Departement Umweltsystemwissenschaften ETH Zürich',
#  'BAK Konjunkturforschung Basel AG',
#  'Trimarca AG',
#  'Wasser- und Energiewirtschaftsamt des Kantons Bern',
#  'Sozialmedizinische Beratungsstelle für Jugendliche Integrative Psych. Winterthur',
#  'Abteilung Biochemie Biozentrum Universität Basel',
#  'Gesundheitsdienst der Stadt Bern',
#  'Sukkulentensammlung Zürich',
#  'FORS c/o Université de Lausanne']

# %% [markdown]
# ## Task 2: Building the Choropleth Map
#
# Swiss maps with the cantons using a DataFrame with Folium
# correct "key_on" value
#
# Fix: AttributeError: 'NoneType' object has no attribute 'get'
#
# **To Use DataFrame for Map**
#
# To use a Dataframe (in the DF, I used the id as the _Cantons_ and I put random values inside the _Values_ field), you need to do this:
# ```python
# swiss_map.choropleth(geo_path=cantons_geo,
#                      data=df,
#                      columns=['Cantons', 'Values'],
#                      key_on='feature.id',
#                      topojson='objects.cantons',
#                      fill_color='YlGn',
#                      legend_name = 'Random numbers'
#                     )
# ```
#
# In you DataFrame, you must be sure that *all the id present in the topojson are also present in the column of the DF*. If it's not the case, just add the missing ids..

# %% [markdown]
# ## Task 3: Bonus
# BONUS: using the map you have just built, and the geographical information contained in it, could you give a rough estimate of the difference in research funding between the areas divided by the Röstigraben?
#
# -- needs Task 1 and Task 2 to be completed, should be less work than task 1 and 2. Probably statistical test.
